# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
Cars = pd.read_csv('https://raw.githubusercontent.com/Kesh12-ux/Assignment-1/refs/heads/main/Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
Cars.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
Cars.columns.values
# Out:
# array(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'], dtype=object)

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
Cars.set_index('name', inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
list(Cars['mpg'].unique())
# Out:
# [np.float64(18.0),
#  np.float64(15.0),
#  np.float64(16.0),
#  np.float64(17.0),
#  np.float64(14.0),
#  np.float64(24.0),
#  np.float64(22.0),
#  np.float64(21.0),
#  np.float64(27.0),
#  np.float64(26.0),
#  np.float64(25.0),
#  np.float64(10.0),
#  np.float64(11.0),
#  np.float64(9.0),
#  np.float64(28.0),
#  np.float64(19.0),
#  np.float64(12.0),
#  np.float64(13.0),
#  np.float64(23.0),
#  np.float64(30.0),
#  np.float64(31.0),
#  np.float64(35.0),
#  np.float64(20.0),
#  np.float64(29.0),
#  np.float64(32.0),
#  np.float64(33.0),
#  np.float64(17.5),
#  np.float64(15.5),
#  np.float64(14.5),
#  np.float64(22.5),
#  np.float64(24.5),
#  np.float64(18.5),
#  np.float64(29.5),
#  np.float64(26.5),
#  np.float64(16.5),
#  np.float64(31.5),
#  np.float64(36.0),
#  np.float64(25.5),
#  np.float64(33.5),
#  np.float64(20.5),
#  np.float64(30.5),
#  np.float64(21.5),
#  np.float64(43.1),
#  np.float64(36.1),
#  np.float64(32.8),
#  np.float64(39.4),
#  np.float64(19.9),
#  np.float64(19.4),
#  np.float64(20.2),
#  np.float64(19.2),
#  np.float64(25.1),
#  np.float64(20.6),
#  np.float64(20.8),
#  np.float64(18.6),
#  np.float64(18.1),
#  np.float64(17.7),
#  np.float64(27.5),
#  np.float64(27.2),
#  np.float64(30.9),
#  np.float64(21.1),
#  np.float64(23.2),
#  np.float64(23.8),
#  np.float64(23.9),
#  np.float64(20.3),
#  np.float64(21.6),
#  np.float64(16.2),
#  np.float64(19.8),
#  np.float64(22.3),
#  np.float64(17.6),
#  np.float64(18.2),
#  np.float64(16.9),
#  np.float64(31.9),
#  np.float64(34.1),
#  np.float64(35.7),
#  np.float64(27.4),
#  np.float64(25.4),
#  np.float64(34.2),
#  np.float64(34.5),
#  np.float64(31.8),
#  np.float64(37.3),
#  np.float64(28.4),
#  np.float64(28.8),
#  np.float64(26.8),
#  np.float64(41.5),
#  np.float64(38.1),
#  np.float64(32.1),
#  np.float64(37.2),
#  np.float64(26.4),
#  np.float64(24.3),
#  np.float64(19.1),
#  np.float64(34.3),
#  np.float64(29.8),
#  np.float64(31.3),
#  np.float64(37.0),
#  np.float64(32.2),
#  np.float64(46.6),
#  np.float64(27.9),
#  np.float64(40.8),
#  np.float64(44.3),
#  np.float64(43.4),
#  np.float64(36.4),
#  np.float64(44.6),
#  np.float64(40.9),
#  np.float64(33.8),
#  np.float64(32.7),
#  np.float64(23.7),
#  np.float64(23.6),
#  np.float64(32.4),
#  np.float64(26.6),
#  np.float64(25.8),
#  np.float64(23.5),
#  np.float64(39.1),
#  np.float64(39.0),
#  np.float64(35.1),
#  np.float64(32.3),
#  np.float64(37.7),
#  np.float64(34.7),
#  np.float64(34.4),
#  np.float64(29.9),
#  np.float64(33.7),
#  np.float64(32.9),
#  np.float64(31.6),
#  np.float64(28.1),
#  np.float64(30.7),
#  np.float64(24.2),
#  np.float64(22.4),
#  np.float64(34.0),
#  np.float64(38.0),
#  np.float64(44.0)]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
Cars['Horsepower/weight'] = Cars['horsepower'] / Cars['weight']
Cars.set_index('Horsepower/weight' , inplace = True)

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
Cars = pd.read_csv('Cars.csv')  
print(Cars.loc[Cars['horsepower'].idxmax(), 'name'])
# Out:
# pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
Cars[Cars['mpg'] >= 35].shape[0]
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
Cars[(Cars['horsepower'] > 100) & (Cars['weight'] < 3000)]['origin'].value_counts().idxmax()
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
round(Cars[Cars['origin'] == 'japan']['acceleration'].mean(), 2)
# Out:
# np.float64(16.17)

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
Cars.groupby('model_year')['mpg'].mean().idxmax()
# Out:
# np.int64(80)

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
Cars = Cars.dropna(subset=['horsepower', 'weight', 'mpg']).copy()
Cars.loc[:, 'horsepower'] = pd.to_numeric(Cars['horsepower'], errors='coerce')
Cars.loc[:, 'weight'] = pd.to_numeric(Cars['weight'], errors='coerce')
Cars = Cars.dropna(subset=['horsepower', 'weight']).copy()

Cars['hp_to_weight'] = Cars['horsepower'] / Cars['weight']
median_mpg = Cars['mpg'].median()
above_median = Cars[Cars['mpg'] > median_mpg]

max_ratio = above_median['hp_to_weight'].max()
best_cars = above_median[above_median['hp_to_weight'] == max_ratio]

best_cars[['name', 'mpg', 'horsepower', 'weight', 'hp_to_weight']]
# Out:
#         name   mpg  horsepower  weight  hp_to_weight
# 23  bmw 2002  26.0       113.0    2234      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
import seaborn as sns
import matplotlib.pyplot as plt

avg_mpg = Cars.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=Cars,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    palette='Set1',
    sizes=(20, 200),
    alpha=0.7
)
plt.title('Horsepower vs Weight (colored by Origin, sized by MPG)')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Origin')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
grouped = Cars.groupby('name').agg(
    count=('model_year', 'nunique'),
    mpg_std=('mpg', 'std'),
    mpg_mean=('mpg', 'mean')
).reset_index()

filtered = grouped[(grouped['count'] >= 2) & (grouped['mpg_std'] < 1.0)]

sorted_result = filtered.sort_values(by=['count', 'mpg_mean'], ascending=[False, False])

sorted_result
# Out:
#                           name  count   mpg_std   mpg_mean
# 140           ford galaxie 500      3  0.577350  14.333333
# 221          plymouth fury iii      3  0.577350  14.333333
# 263        toyota corolla 1200      2  0.707107  31.500000
# 173                  mazda 626      2  0.212132  31.450000
# 283          volkswagen rabbit      2  0.353553  29.250000
# 94                datsun pl510      2  0.000000  27.000000
# 256                  saab 99le      2  0.707107  24.500000
# 272             toyota mark ii      2  0.707107  19.500000
# 97                 dodge aspen      2  0.353553  18.850000
# 48   chevrolet chevelle malibu      2  0.707107  17.500000
# 10            amc matador (sw)      2  0.707107  14.500000
# 142      ford gran torino (sw)      2  0.707107  13.500000
# 147                   ford ltd      2  0.707107  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
